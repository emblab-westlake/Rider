# %%
import pandas as pd
from Bio import SeqIO

path="all_prodigalgv.fasta_alnRes.m8"
df=pd.read_csv(path, sep="\t",header=None)
df.columns=['id', 'sub_id', 'identity', 'alignLen', 'mismat', 'gapOpens', 'qStart', 'qEnd', 'sStart', 'sEnd', 'eval', 'bit']
df
# Out:
#                         id          sub_id  identity  alignLen  mismat  \
# 0    SRR5947934_k99_2885_3  YP_009238487.1     0.387        49      29
# 1    SRR5947934_k99_2885_3  YP_009237897.1     0.387        49      29
# 2    SRR5947905_k99_2644_2     YP_724457.1     0.284       135      83
# 3    SRR5947905_k99_2644_2     YP_720001.1     0.284       135      83
# 4    SRR5947934_k99_1513_1  YP_009552830.1     0.555        27      12
# ..                     ...             ...       ...       ...     ...
# 483  SRR5947895_k99_8782_2  YP_009237900.1     0.406        57      33
# 484  SRR5947896_k99_5757_1  YP_009238487.1     0.387        49      29
# 485  SRR5947896_k99_5757_1  YP_009237897.1     0.387        49      29
# 486  SRR5947896_k99_5757_1  YP_009528582.1     0.386        44      26
# 487  SRR5947896_k99_5757_1  YP_009518835.1     0.386        44      26
#
#      gapOpens  qStart  qEnd  sStart  sEnd      eval  bit
# 0           0     545   593     138   185  0.000776   36
# 1           0     545   593     468   515  0.000776   36
# 2           0     104   238      65   181  0.000269   36
# 3           0     104   238     406   522  0.000269   36
# 4           0      42    68     394   420  0.000194   34
# ..        ...     ...   ...     ...   ...       ...  ...
# 483         0      29    85     456   512  0.000420   35
# 484         0     158   206     138   185  0.000365   36
# 485         0     158   206     468   515  0.000365   36
# 486         0     158   201     138   180  0.000840   35
# 487         0     158   201     471   513  0.000840   35
#
# [488 rows x 12 columns]

# %%
filter_df=df[(df['identity'] > 0.5) & (df['alignLen'] > 40)]
filter_df
# Out:
#                        id          sub_id  identity  alignLen  mismat  \
# 77   SRR5947958_k99_495_3  YP_009538340.1     0.982      1795      32
# 78   SRR5947958_k99_495_3  YP_009305194.1     0.979      1769      37
# 79   SRR5947958_k99_495_3  YP_009700102.2     0.953      1795      84
# 80   SRR5947958_k99_495_3  YP_009700096.1     0.768      1795     414
# 81   SRR5947958_k99_495_3     NP_056820.1     0.770      1795     410
# ..                    ...             ...       ...       ...     ...
# 460  SRR5947958_k99_495_1  YP_009305196.1     0.773       215      49
# 461  SRR5947958_k99_495_1  YP_009700104.1     0.718       215      60
# 462  SRR5947958_k99_495_1  YP_009700098.1     0.647       213      73
# 463  SRR5947958_k99_495_1  YP_009700095.1     0.647       213      73
# 464  SRR5947958_k99_495_1     NP_056822.1     0.635       212      76
#
#      gapOpens  qStart  qEnd  sStart  sEnd          eval   bit
# 77          0       1  1795       5  1799  0.000000e+00  3619
# 78          0      27  1795       1  1769  0.000000e+00  3553
# 79          0       1  1795       5  1799  0.000000e+00  3531
# 80          0       1  1795       5  1788  0.000000e+00  2904
# 81          0       1  1795       5  1789  0.000000e+00  2897
# ..        ...     ...   ...     ...   ...           ...   ...
# 460         0       1   215       1   215  6.148000e-98   308
# 461         0       1   215       1   215  2.844000e-90   286
# 462         0       1   213       1   208  3.594000e-73   237
# 463         0       1   213       1   208  6.746000e-73   236
# 464         0       1   212       1   209  1.266000e-72   235
#
# [93 rows x 12 columns]

# %%
print(len(set(filter_df.iloc[:,0].to_list())))
a=set(filter_df.iloc[:,0].to_list())
a
# Out:
# 3
# {'SRR5947958_k99_495_1', 'SRR5947958_k99_495_2', 'SRR5947958_k99_495_3'}
